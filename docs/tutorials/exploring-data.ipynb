# %% [markdown]
# # Exploring data
#
# When working with a dataset, the first step is usually to understand what data and metadata it contains.
# In this chapter we explore how scipp supports this.
#
# This tutorial contains exercises, but solutions are included directly.
# We encourage you to download this notebook and run through it step by step before looking at the solutions.
#
# First, in addition to importing `scipp`, we import `scippneutron` since this is required for loading Nexus files:

# %%
import scipp as sc
import scippneutron as scn
import numpy as np
# Out:
# You are running a "Debug" build of scipp. For optimal performance use a "Release" build.

# %% [markdown]
# We  start by loading some data (download [here](https://github.com/ess-dmsc-dram/loki_tube_scripts/raw/master/test/test_data/LARMOR00049338.nxs)), in this case measured with a prototype of the [LoKI](https://europeanspallationsource.se/instruments/loki) detectors at the [LARMOR beamline](https://www.isis.stfc.ac.uk/Pages/Larmor.aspx):

# %%
data = scn.load(filename='/Users/spu92482/Downloads/LARMOR00049338.nxs')
# Out:
# Workspace run log 'good_frames' has unrecognised units: 'frames'
# Workspace run log 'raw_frames' has unrecognised units: 'frames'

# %% [markdown]
# Note that the exercises in the following are fictional and do not represent the actual SANS data reduction workflow.

# %% [markdown]
# ### Step 1: Use the HTML representation to see what the loaded data contains
#
# The HTML representation is what Jupyter displays for a scipp object.
# - Take some time to explore this view and try to understand all the information (dimensions, dtypes, units, ...).
# - Note that sections can be expanded, and values can shown by clicking the icons to the right.

# %%
data
# Out:
# ---------------------------------------------------------------------------
# BinEdgeError                              Traceback (most recent call last)
# ~/miniconda3/envs/scippneutron-developer-next/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/builds/scipp_debug_clion/install/scipp/html/__init__.py in make_html(container)
#      12         return variable_repr(container)
#      13     else:
# ---> 14         return dataset_repr(container)
#      15
#      16
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in dataset_repr(ds)
#     476         sections.append(coord_section(ds.coords, ds))
#     477
# --> 478     sections.append(data_section(ds if is_dataset(ds) else {'': ds}))
#     479
#     480     if not is_dataset(ds):
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in _mapping_section(mapping, name, details_func, max_items_collapse, enabled, *extra_details_func_args)
#     384     return collapsible_section(
#     385         name,
# --> 386         details=details_func(mapping, *extra_details_func_args),
#     387         n_items=n_items,
#     388         enabled=enabled,
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in summarize_data(dataset)
#     346                            has_attrs=has_attrs,
#     347                            embedded_in=dataset if has_attrs else None))
# --> 348                       for name, var in _ordered_dict(dataset).items())
#     349     return f"<ul class='sc-var-list'>{vars_li}</ul>"
#     350
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in <genexpr>(.0)
#     346                            has_attrs=has_attrs,
#     347                            embedded_in=dataset if has_attrs else None))
# --> 348                       for name, var in _ordered_dict(dataset).items())
#     349     return f"<ul class='sc-var-list'>{vars_li}</ul>"
#     350
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in summarize_variable(name, var, is_index, has_attrs, embedded_in, add_dim_size)
#     296     disabled, attrs_ul = _make_inline_attributes(var, has_attrs, embedded_in)
#     297
# --> 298     preview = inline_variable_repr(var)
#     299     data_repr = f"Values:<br>{short_data_repr_html(var)}"
#     300     variances_preview = None
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in inline_variable_repr(var, has_variances)
#     115 def inline_variable_repr(var, has_variances=False):
#     116     if var.bins is None:
# --> 117         return _format_non_events(var, has_variances)
#     118     else:
#     119         return _format_events(var, has_variances)
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in _format_non_events(var, has_variances)
#      49     size = reduce(operator.mul, var.shape, 1)
#      50     if len(var.dims):
# ---> 51         var = sc.flatten(var, var.dims, 'ignored')
#      52     data = retrieve(var, variances=has_variances)
#      53     # avoid unintentional indexing into value of 0-D data
#
# BinEdgeError: Flatten: the bin edges cannot be joined together.
# <scipp.DataArray>
# Dimensions: Sizes[spectrum:114688, tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  (spectrum)  [(0.778000, 0.130467, 29.858778), (0.775065, 0.130467, 29.858778), ..., (-0.569652, -0.022866, 29.953283), (-0.572000, -0.022866, 29.953283)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   spectrum                    int32  [dimensionless]  (spectrum)  [11, 12, ..., 114697, 114698]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (spectrum, tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   A1HCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000600, 0.000600, ..., 0.000600, 0.000600]
#
# ]
#   A1HGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [19.999201, 19.999201, ..., 19.999201, 19.999201]
#
# ]
#   A1VCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.001650, -0.001650, ..., -0.001650, -0.001650]
#
# ]
#   A1VGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [20.000500, 20.000500, ..., 20.000500, 20.000500]
#
# ]
#   Ana_Arc                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   Ana_Trans               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   BenchLift               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   BenchStatus             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   Bench_Rot               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [89.998398, 89.998398, ..., 89.998398, 89.998398]
#
# ]
#   BlockhouseVacuum        DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.650000, 0.650000, ..., 0.650000, 0.650000]
#
# ]
#   CJHCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000350, -0.000350, ..., -0.000350, -0.000350]
#
# ]
#   CJHGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [34.999100, 34.999100, ..., 34.999100, 34.999100]
#
# ]
#   CJVCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.002150, 0.002150, ..., 0.002150, 0.002150]
#
# ]
#   CJVGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [34.990898, 34.990898, ..., 34.990898, 34.990898]
#
# ]
#   ChangerTranslation      DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-251.000000, -251.000000, ..., -251.000000, -251.000000]
#
# ]
#   Chi                     DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.099956, -0.099956, ..., -0.099956, -0.099956]
#
# ]
#   CoarseZ                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-125.000000, -125.000000, ..., -125.000000, -125.000000]
#
# ]
#   DCMagField1             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.002000, -0.002000, ..., -0.002000, -0.002000]
#
# ]
#   DCMagField2             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   DCMagField3             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1.085000, -1.085000, ..., -1.085000, -1.085000]
#
# ]
#   DCMagField4             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1.752000, -1.752000, ..., -1.752000, -1.752000]
#
# ]
#   EPICS_PUTLOG            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:5, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:12.000000000, 2019-12-16T17:53:31.000000000, ..., 2019-12-16T17:53:48.000000000, 2019-12-16T17:53:48.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["Changed PV: IN:LARMOR:DAE:ENDRUN new=1 old=0     ", "Changed PV: IN:LARMOR:DAE:TITLE:SP new=76 old=83 ", ..., "Changed PV: IN:LARMOR:DAE:BEGINRUN new=1 old=1   ", "Changed PV: IN:LARMOR:DAE:ENDSEWAIT new=1 old=1  "]
#
# ]
#   Echo_Coil               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   Echo_Coil_SP            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   FineZ                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.161000, 0.161000, ..., 0.161000, 0.161000]
#
# ]
#   ICP_DAE_TD              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:16, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [46520.398438, 46520.398438, ..., 46520.398438, 46520.398438]
#
# ]
#   ICP_SYS_TD              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:16, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-3.272500, -3.272500, ..., -3.272500, -3.272500]
#
# ]
#   IncidentVacuum          DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.002800, 0.002800, ..., 0.002800, 0.002800]
#
# ]
#   InstrumentDiskPhase     DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [2450.000000, 2450.000000, ..., 2450.000000, 2450.000000]
#
# ]
#   M3Height                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000025, -0.000025, ..., -0.000025, -0.000025]
#
# ]
#   M4Trans                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.002400, 0.002400, ..., 0.002400, 0.002400]
#
# ]
#   Mag1_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.420803, -63.420803, ..., -63.420803, -63.420803]
#
# ]
#   Mag1_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [3399.998535, 3399.998535, ..., 3399.998535, 3399.998535]
#
# ]
#   Mag1_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-302.004730, -302.004730, ..., -302.004791, -302.004791]
#
# ]
#   Mag1_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [302.002960, 302.002960, ..., 302.002960, 302.002960]
#
# ]
#   Mag2_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.406376, -63.406376, ..., -63.406376, -63.406376]
#
# ]
#   Mag2_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [2300.013672, 2300.013672, ..., 2300.013672, 2300.013672]
#
# ]
#   Mag2_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-307.008453, -307.008453, ..., -307.008453, -307.008453]
#
# ]
#   Mag2_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [308.001160, 308.001160, ..., 308.001190, 308.001190]
#
# ]
#   Mag3_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.020290, -63.020290, ..., -63.020290, -63.020290]
#
# ]
#   Mag3_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1130.002197, -1130.002197, ..., -1130.002197, -1130.002197]
#
# ]
#   Mag3_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-370.004608, -370.004608, ..., -370.004608, -370.004608]
#
# ]
#   Mag3_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [370.003387, 370.003387, ..., 370.003387, 370.003387]
#
# ]
#   Mag4_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.020111, -63.020111, ..., -63.020111, -63.020111]
#
# ]
#   Mag4_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1800.000244, -1800.000244, ..., -1800.000244, -1800.000244]
#
# ]
#   Mag4_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-370.009460, -370.009460, ..., -370.009491, -370.009491]
#
# ]
#   Mag4_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [369.999390, 369.999390, ..., 369.999390, 369.999390]
#
# ]
#   Moderator_Temp          DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [17.879999, 17.879999, ..., 17.879999, 17.879999]
#
# ]
#   Pol_Position            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:51.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["FOM", "FOM"]
#
# ]
#   Psi                     DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.348938, -0.348938, ..., -0.348938, -0.348938]
#
# ]
#   RFCoilTemp1             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [21.499756, 21.499756, ..., 21.494925, 21.494925]
#
# ]
#   RFCoilTemp2             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [21.771128, 21.771128, ..., 21.762672, 21.762672]
#
# ]
#   RFCoilTemp3             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [23.484751, 23.484751, ..., 23.466646, 23.466646]
#
# ]
#   RFCoilTemp4             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [26.476938, 26.476938, ..., 26.457626, 26.457626]
#
# ]
#   S1HCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.003400, 0.003400, ..., 0.003400, 0.003400]
#
# ]
#   S1HGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [13.001600, 13.001600, ..., 13.001600, 13.001600]
#
# ]
#   S1VCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.002500, -0.002500, ..., -0.002500, -0.002500]
#
# ]
#   S1VGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [13.007600, 13.007600, ..., 13.007600, 13.007600]
#
# ]
#   S2HCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.001500, -0.001500, ..., -0.001500, -0.001500]
#
# ]
#   S2HGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000800, -0.000800, ..., -0.000800, -0.000800]
#
# ]
#   S2VCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000500, -0.000500, ..., -0.000500, -0.000500]
#
# ]
#   S2VGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000600, -0.000600, ..., -0.000600, -0.000600]
#
# ]
#   SANSTank_Vacuum         DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.030000, 0.030000, ..., 0.030000, 0.030000]
#
# ]
#   SamplePos               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:51.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["CT", "CT"]
#
# ]
#   SampleX                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [15.004000, 15.004000, ..., 15.004000, 15.004000]
#
# ]
#   ShutterPosition         DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [1.000000, 1.000000, ..., 1.000000, 1.000000]
#
# ]
#   SimL1                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [800.000000, 800.000000, ..., 800.000000, 800.000000]
#
# ]
#   SimL2                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [800.000000, 800.000000, ..., 800.000000, 800.000000]
#
# ]
#   SimPSO                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [100.000000, 100.000000, ..., 100.000000, 100.000000]
#
# ]
#   SimTheta                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-20.000000, -20.000000, ..., -20.000000, -20.000000]
#
# ]
#   T0Phase                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   TargetDiskPhase         DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [2750.000000, 2750.000000, ..., 2750.000000, 2750.000000]
#
# ]
#   Theta                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.003015, -0.003015, ..., -0.003015, -0.003015]
#
# ]
#   Translation             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.893000, -0.893000, ..., -0.893000, -0.893000]
#
# ]
#   a2_height               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [16.830000, 16.830000, ..., 16.830000, 16.830000]
#
# ]
#   a2_trans                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [11.680000, 11.680000, ..., 11.680000, 11.680000]
#
# ]
#   count_rate              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64         [counts]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   current_period              int64  [dimensionless]  ()  [1]
#   dae_beam_current        DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64           [µAh]  (time)  [0.000000, 0.000000, ..., 175.565994, 175.565994]
#
# ]
#   dmp                         int64  [dimensionless]  ()  [0]
#   dmp_freq                    int64  [dimensionless]  ()  [0]
#   dmp_units                   int64  [dimensionless]  ()  [0]
#   dur                         int64  [dimensionless]  ()  [56]
#   dur_freq                    int64  [dimensionless]  ()  [0]
#   dur_secs                    int64  [dimensionless]  ()  [7]
#   dur_wanted                  int64  [dimensionless]  ()  [0]
#   durunits                    int64  [dimensionless]  ()  [1]
#   end_time                   string  [dimensionless]  ()  ["2019-12-18T18:36:41"]
#   flipper_onoff           DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [1.000000, 1.000000, ..., 1.000000, 1.000000]
#
# ]
#   freq                        int64  [dimensionless]  ()  [1]
#   gd_prtn_chrg              float64  [dimensionless]  ()  [2.750211]
#   good_frames             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1461, 258]
#
# ]
#   good_uah_log            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64           [µAh]  (time)  [1.460050, 1.460050, ..., 0.257832, 0.257832]
#
# ]
#   goodfrm                     int64  [dimensionless]  ()  [2752]
#   icp_event               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:5, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000, 2019-12-16T17:53:49.000000000, ..., 2019-12-16T17:53:56.000000000, 2019-12-16T17:53:56.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["CHANGE_PERIOD 1                                           ", "START_COLLECTION PERIOD 1 GF 0 RF 0 GUAH 0.000000         ", ..., "STOP_COLLECTION PERIOD 1 GF 344 RF 344 GUAH 0.343776 DUR 7", "END                                                       "]
#
# ]
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   is_running              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [0, 0]
#
# ]
#   is_waiting              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [0, 0]
#
# ]
#   measurement_id             string  [dimensionless]  ()  ["0"]
#   measurement_label          string  [dimensionless]  ()  [""]
#   measurement_subid          string  [dimensionless]  ()  ["0"]
#   measurement_type           string  [dimensionless]  ()  ["sans"]
#   mon_sum1                    int64  [dimensionless]  ()  [0]
#   mon_sum2                    int64  [dimensionless]  ()  [0]
#   mon_sum3                    int64  [dimensionless]  ()  [0]
#   monitor1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 9.819500)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [287.000000, 147.000000, ..., 14.000000, 3986.000000]  [287.000000, 147.000000, ..., 14.000000, 3986.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [1]
#
# ]
#   monitor2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 20.313000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [6.000000, 11.000000, ..., 4.000000, 8.000000]  [6.000000, 11.000000, ..., 4.000000, 8.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [2]
#
# ]
#   monitor3                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 24.056000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [3]
#
# ]
#   monitor4                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.760000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [28.000000, 34.000000, ..., 11.000000, 25.000000]  [28.000000, 34.000000, ..., 11.000000, 25.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [4]
#
# ]
#   monitor5                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 29.650000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [5]
#
# ]
#   monitor_sum_1           DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32         [counts]  (time)  [0, 0]
#
# ]
#   nchannels                   int64  [dimensionless]  ()  [1000]
#   np_ratio                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   nperiods                    int64  [dimensionless]  ()  [1]
#   nspectra                    int64  [dimensionless]  ()  [114698]
#   period                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1, 1]
#
# ]
#   period 1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:1, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000]
# Data:
#                                bool  [dimensionless]  (time)  [True]
#
# ]
#   periods                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:1, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1]
#
# ]
#   placeholder monitor_10  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [10]
#
# ]
#   placeholder monitor_6   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [6]
#
# ]
#   placeholder monitor_7   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [7]
#
# ]
#   placeholder monitor_8   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [8]
#
# ]
#   placeholder monitor_9   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [9]
#
# ]
#   pol_arc                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.083941, -0.083941, ..., -0.083941, -0.083941]
#
# ]
#   pol_trans               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   proton_charge_by_period   float64  [dimensionless]  ()  [0.343776]
#   raw_frames              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1461, 258]
#
# ]
#   raw_uah_log             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64           [µAh]  (time)  [1.460050, 1.460050, ..., 0.257832, 0.257832]
#
# ]
#   rawfrm                      int64  [dimensionless]  ()  [2752]
#   rb_proposal                 int64  [dimensionless]  ()  [1930522]
#   run_end                    string  [dimensionless]  ()  ["2019-12-18T18:36:41"]
#   run_header                 string  [dimensionless]  ()  ["LAR 49293 Dalgliesh,Raspino,Ho  LOKI Detector Test Dumm 16-DEC-2019  17:53:49     0.34"]
#   run_number                 string  [dimensionless]  ()  ["49338"]
#   run_start                  string  [dimensionless]  ()  ["2019-12-18T17:36:11"]
#   run_status              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1, 1]
#
# ]
#   run_title                  string  [dimensionless]  ()  ["RT1 a1=20x20 a2=6x8mm_SANS"]
#   running                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000, 2019-12-16T17:53:56.000000000]
# Data:
#                                bool  [dimensionless]  (time)  [True, False]
#
# ]
#   s2south                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000200, -0.000200, ..., -0.000200, -0.000200]
#
# ]
#   sample                   PyObject  [dimensionless]  ()  [<mantid.api._api.Sample object at 0x7f7f01590f80>]
#   smc100_1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-125.000000, -125.000000, ..., -125.000000, -125.000000]
#
# ]
#   spinflipper_curr        DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:184, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [5.900000, 5.800000, ..., 5.900000, 5.900000]
#
# ]
#   start_time                 string  [dimensionless]  ()  ["2019-12-18T17:36:11"]
#   tot_prtn_chrg             float64  [dimensionless]  ()  [2.750211]
#   total_counts            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32         [counts]  (time)  [0, 0]
#
# ]

# %% [markdown]
# ### Step 2: Plot the data
#
# Scipp objects can be created using the `plot()` method.
# Alternatively `sc.plot(obj)` can be used.
# Since this is neutron-scattering data, we can also use the "instrument view", provided by `scn.instrument_view(obj)` (assuming `scippneutron` was imported as `scn`).
#
# - Plot the loaded data and familiarize yourself with the controls.
# - Create the instrument view and familiarize yourself with the controls.

# %%
data.plot()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %%
scn.instrument_view(data)
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %% [markdown]
# ### Step 3: Exploring meta data
#
# Above we saw that many attributes are scalar variables with `dtype=DataArray`.
# The single value in a scalar variable is accessed using the `value` property.
# Compare:

# %%
data.attrs['proton_charge_by_period']
# Out:
# <scipp.Variable> ()    float64  [dimensionless]  [0.343776]

# %%
data.attrs['proton_charge_by_period'].value
# Out:
# 0.3437764048576355

# %% [markdown]
# Exercises:
# 1. Find some attributes of `data` with `dtype=DataArray` and plot their `value`.
#    Also try `sc.table(attr.value)` to show a table representation.
# 2. Find and plot a monitor.
# 3. Try to normalize `data` to monitor 1.
#    Why does this fail?
# 4. Plot all the monitors on the same plot.
#    Note that `sc.plot()` can be used with a Python `dict` for this purpose: `sc.plot({'a':something, 'b':else})`.
# 5. Convert all the monitors from `'tof'` to `'wavelength'` using, e.g., `mon1_wav = sc.neutron.convert(mon1, 'tof', 'wavelength', scatter=False)`.
# 6. Inspect the HTML view and note how the "unit conversion" changed the dimensions and units.
# 7. Re-plot all the monitors on the same plot, now in `'wavelength'`.

# %%
sc.table(data.attrs['DCMagField2'].value)
# Out:
# VBox(children=(HTML(value="<span class='sc-title'>DataArray</span>"), VBox(children=(HTML(value="<span class='…

# %%
try:
    data / data.attrs['monitor1'].value
except sc.CoordError:
    print('Data and monitor are in unit TOF, but pixels and monitors are at different position, so data is not comparable')
# Out:
# Data and monitor are in unit TOF, but pixels and monitors are at different position, so data is not comparable

# %%
mon1 = data.attrs['monitor1'].value
scn.convert(mon1, 'tof', 'wavelength', scatter=False)
# Out:
# <scipp.DataArray>
# Dimensions: Sizes[wavelength:1000, ]
# Coordinates:
#   wavelength                float64             [Å]  (wavelength [bin-edge])  [0.002014, 0.042302, ..., 40.249257, 40.287530]
# Data:
#                             float64         [counts]  (wavelength)  [287.000000, 147.000000, ..., 14.000000, 3986.000000]  [287.000000, 147.000000, ..., 14.000000, 3986.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 9.819500)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   spectrum                    int32  [dimensionless]  ()  [1]

# %%
sc.plot({f'monitor{i}':data.attrs[f'monitor{i}'].value for i in [1,2,3,4,5]}, norm='log')
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %%
sc.plot({f'monitor{i}':scn.convert(data.attrs[f'monitor{i}'].value, 'tof', 'wavelength', scatter=False) for i in [1,2,3,4,5]}, norm='log')
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %% [markdown]
# ### Step 4: Fixing metadata
#
# Exercises:
# 1. The `sample_position` coord is wrong, shift the sample by `delta = sc.scalar(value=np.array([0.01,0.01,0.04]), unit=sc.units.m)`.
# 2. Because of a glitch in the timing system the time-of-flight has an offset of $2.3~\mu s$.
#    Fix the corresponding coordinate.
# 3. Use the HTML view of `data` to verify that you applied the corrections/calibrations there, rather than in a copy.

# %%
data.coords['sample_position'] += sc.vector(value=[0.01,0.01,0.04], unit=sc.units.m)
data.coords['tof'] += 2.3 * sc.Unit('us') # note how we forgot to fix the monitor's TOF
data
# Out:
# ---------------------------------------------------------------------------
# BinEdgeError                              Traceback (most recent call last)
# ~/miniconda3/envs/scippneutron-developer-next/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/builds/scipp_debug_clion/install/scipp/html/__init__.py in make_html(container)
#      12         return variable_repr(container)
#      13     else:
# ---> 14         return dataset_repr(container)
#      15
#      16
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in dataset_repr(ds)
#     476         sections.append(coord_section(ds.coords, ds))
#     477
# --> 478     sections.append(data_section(ds if is_dataset(ds) else {'': ds}))
#     479
#     480     if not is_dataset(ds):
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in _mapping_section(mapping, name, details_func, max_items_collapse, enabled, *extra_details_func_args)
#     384     return collapsible_section(
#     385         name,
# --> 386         details=details_func(mapping, *extra_details_func_args),
#     387         n_items=n_items,
#     388         enabled=enabled,
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in summarize_data(dataset)
#     346                            has_attrs=has_attrs,
#     347                            embedded_in=dataset if has_attrs else None))
# --> 348                       for name, var in _ordered_dict(dataset).items())
#     349     return f"<ul class='sc-var-list'>{vars_li}</ul>"
#     350
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in <genexpr>(.0)
#     346                            has_attrs=has_attrs,
#     347                            embedded_in=dataset if has_attrs else None))
# --> 348                       for name, var in _ordered_dict(dataset).items())
#     349     return f"<ul class='sc-var-list'>{vars_li}</ul>"
#     350
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in summarize_variable(name, var, is_index, has_attrs, embedded_in, add_dim_size)
#     296     disabled, attrs_ul = _make_inline_attributes(var, has_attrs, embedded_in)
#     297
# --> 298     preview = inline_variable_repr(var)
#     299     data_repr = f"Values:<br>{short_data_repr_html(var)}"
#     300     variances_preview = None
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in inline_variable_repr(var, has_variances)
#     115 def inline_variable_repr(var, has_variances=False):
#     116     if var.bins is None:
# --> 117         return _format_non_events(var, has_variances)
#     118     else:
#     119         return _format_events(var, has_variances)
#
# ~/builds/scipp_debug_clion/install/scipp/html/formatting_html.py in _format_non_events(var, has_variances)
#      49     size = reduce(operator.mul, var.shape, 1)
#      50     if len(var.dims):
# ---> 51         var = sc.flatten(var, var.dims, 'ignored')
#      52     data = retrieve(var, variances=has_variances)
#      53     # avoid unintentional indexing into value of 0-D data
#
# BinEdgeError: Flatten: the bin edges cannot be joined together.
# <scipp.DataArray>
# Dimensions: Sizes[spectrum:114688, tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  (spectrum)  [(0.778000, 0.130467, 29.858778), (0.775065, 0.130467, 29.858778), ..., (-0.569652, -0.022866, 29.953283), (-0.572000, -0.022866, 29.953283)]
#   sample_position         vector_3_float64              [m]  ()  [(0.010000, 0.010000, 25.340000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   spectrum                    int32  [dimensionless]  (spectrum)  [11, 12, ..., 114697, 114698]
#   tof                       float64            [µs]  (tof [bin-edge])  [7.300000, 107.300000, ..., 99907.300000, 100002.300000]
# Data:
#                             float64         [counts]  (spectrum, tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   A1HCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000600, 0.000600, ..., 0.000600, 0.000600]
#
# ]
#   A1HGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [19.999201, 19.999201, ..., 19.999201, 19.999201]
#
# ]
#   A1VCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.001650, -0.001650, ..., -0.001650, -0.001650]
#
# ]
#   A1VGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [20.000500, 20.000500, ..., 20.000500, 20.000500]
#
# ]
#   Ana_Arc                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   Ana_Trans               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   BenchLift               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   BenchStatus             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   Bench_Rot               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [89.998398, 89.998398, ..., 89.998398, 89.998398]
#
# ]
#   BlockhouseVacuum        DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.650000, 0.650000, ..., 0.650000, 0.650000]
#
# ]
#   CJHCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000350, -0.000350, ..., -0.000350, -0.000350]
#
# ]
#   CJHGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [34.999100, 34.999100, ..., 34.999100, 34.999100]
#
# ]
#   CJVCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.002150, 0.002150, ..., 0.002150, 0.002150]
#
# ]
#   CJVGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [34.990898, 34.990898, ..., 34.990898, 34.990898]
#
# ]
#   ChangerTranslation      DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-251.000000, -251.000000, ..., -251.000000, -251.000000]
#
# ]
#   Chi                     DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.099956, -0.099956, ..., -0.099956, -0.099956]
#
# ]
#   CoarseZ                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-125.000000, -125.000000, ..., -125.000000, -125.000000]
#
# ]
#   DCMagField1             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.002000, -0.002000, ..., -0.002000, -0.002000]
#
# ]
#   DCMagField2             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   DCMagField3             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1.085000, -1.085000, ..., -1.085000, -1.085000]
#
# ]
#   DCMagField4             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1.752000, -1.752000, ..., -1.752000, -1.752000]
#
# ]
#   EPICS_PUTLOG            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:5, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:12.000000000, 2019-12-16T17:53:31.000000000, ..., 2019-12-16T17:53:48.000000000, 2019-12-16T17:53:48.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["Changed PV: IN:LARMOR:DAE:ENDRUN new=1 old=0     ", "Changed PV: IN:LARMOR:DAE:TITLE:SP new=76 old=83 ", ..., "Changed PV: IN:LARMOR:DAE:BEGINRUN new=1 old=1   ", "Changed PV: IN:LARMOR:DAE:ENDSEWAIT new=1 old=1  "]
#
# ]
#   Echo_Coil               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   Echo_Coil_SP            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   FineZ                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.161000, 0.161000, ..., 0.161000, 0.161000]
#
# ]
#   ICP_DAE_TD              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:16, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [46520.398438, 46520.398438, ..., 46520.398438, 46520.398438]
#
# ]
#   ICP_SYS_TD              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:16, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-3.272500, -3.272500, ..., -3.272500, -3.272500]
#
# ]
#   IncidentVacuum          DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.002800, 0.002800, ..., 0.002800, 0.002800]
#
# ]
#   InstrumentDiskPhase     DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [2450.000000, 2450.000000, ..., 2450.000000, 2450.000000]
#
# ]
#   M3Height                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000025, -0.000025, ..., -0.000025, -0.000025]
#
# ]
#   M4Trans                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.002400, 0.002400, ..., 0.002400, 0.002400]
#
# ]
#   Mag1_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.420803, -63.420803, ..., -63.420803, -63.420803]
#
# ]
#   Mag1_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [3399.998535, 3399.998535, ..., 3399.998535, 3399.998535]
#
# ]
#   Mag1_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-302.004730, -302.004730, ..., -302.004791, -302.004791]
#
# ]
#   Mag1_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [302.002960, 302.002960, ..., 302.002960, 302.002960]
#
# ]
#   Mag2_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.406376, -63.406376, ..., -63.406376, -63.406376]
#
# ]
#   Mag2_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [2300.013672, 2300.013672, ..., 2300.013672, 2300.013672]
#
# ]
#   Mag2_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-307.008453, -307.008453, ..., -307.008453, -307.008453]
#
# ]
#   Mag2_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [308.001160, 308.001160, ..., 308.001190, 308.001190]
#
# ]
#   Mag3_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.020290, -63.020290, ..., -63.020290, -63.020290]
#
# ]
#   Mag3_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1130.002197, -1130.002197, ..., -1130.002197, -1130.002197]
#
# ]
#   Mag3_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-370.004608, -370.004608, ..., -370.004608, -370.004608]
#
# ]
#   Mag3_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [370.003387, 370.003387, ..., 370.003387, 370.003387]
#
# ]
#   Mag4_Theta              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-63.020111, -63.020111, ..., -63.020111, -63.020111]
#
# ]
#   Mag4_Tx0                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-1800.000244, -1800.000244, ..., -1800.000244, -1800.000244]
#
# ]
#   Mag4_Ty1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-370.009460, -370.009460, ..., -370.009491, -370.009491]
#
# ]
#   Mag4_Ty2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [369.999390, 369.999390, ..., 369.999390, 369.999390]
#
# ]
#   Moderator_Temp          DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [17.879999, 17.879999, ..., 17.879999, 17.879999]
#
# ]
#   Pol_Position            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:51.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["FOM", "FOM"]
#
# ]
#   Psi                     DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.348938, -0.348938, ..., -0.348938, -0.348938]
#
# ]
#   RFCoilTemp1             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [21.499756, 21.499756, ..., 21.494925, 21.494925]
#
# ]
#   RFCoilTemp2             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [21.771128, 21.771128, ..., 21.762672, 21.762672]
#
# ]
#   RFCoilTemp3             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [23.484751, 23.484751, ..., 23.466646, 23.466646]
#
# ]
#   RFCoilTemp4             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [26.476938, 26.476938, ..., 26.457626, 26.457626]
#
# ]
#   S1HCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.003400, 0.003400, ..., 0.003400, 0.003400]
#
# ]
#   S1HGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [13.001600, 13.001600, ..., 13.001600, 13.001600]
#
# ]
#   S1VCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.002500, -0.002500, ..., -0.002500, -0.002500]
#
# ]
#   S1VGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [13.007600, 13.007600, ..., 13.007600, 13.007600]
#
# ]
#   S2HCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.001500, -0.001500, ..., -0.001500, -0.001500]
#
# ]
#   S2HGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000800, -0.000800, ..., -0.000800, -0.000800]
#
# ]
#   S2VCent                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000500, -0.000500, ..., -0.000500, -0.000500]
#
# ]
#   S2VGap                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000600, -0.000600, ..., -0.000600, -0.000600]
#
# ]
#   SANSTank_Vacuum         DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.030000, 0.030000, ..., 0.030000, 0.030000]
#
# ]
#   SamplePos               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:51.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["CT", "CT"]
#
# ]
#   SampleX                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [15.004000, 15.004000, ..., 15.004000, 15.004000]
#
# ]
#   ShutterPosition         DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [1.000000, 1.000000, ..., 1.000000, 1.000000]
#
# ]
#   SimL1                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [800.000000, 800.000000, ..., 800.000000, 800.000000]
#
# ]
#   SimL2                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [800.000000, 800.000000, ..., 800.000000, 800.000000]
#
# ]
#   SimPSO                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [100.000000, 100.000000, ..., 100.000000, 100.000000]
#
# ]
#   SimTheta                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-20.000000, -20.000000, ..., -20.000000, -20.000000]
#
# ]
#   T0Phase                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   TargetDiskPhase         DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [2750.000000, 2750.000000, ..., 2750.000000, 2750.000000]
#
# ]
#   Theta                   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.003015, -0.003015, ..., -0.003015, -0.003015]
#
# ]
#   Translation             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.893000, -0.893000, ..., -0.893000, -0.893000]
#
# ]
#   a2_height               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [16.830000, 16.830000, ..., 16.830000, 16.830000]
#
# ]
#   a2_trans                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [11.680000, 11.680000, ..., 11.680000, 11.680000]
#
# ]
#   count_rate              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64         [counts]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   current_period              int64  [dimensionless]  ()  [1]
#   dae_beam_current        DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64           [µAh]  (time)  [0.000000, 0.000000, ..., 175.565994, 175.565994]
#
# ]
#   dmp                         int64  [dimensionless]  ()  [0]
#   dmp_freq                    int64  [dimensionless]  ()  [0]
#   dmp_units                   int64  [dimensionless]  ()  [0]
#   dur                         int64  [dimensionless]  ()  [56]
#   dur_freq                    int64  [dimensionless]  ()  [0]
#   dur_secs                    int64  [dimensionless]  ()  [7]
#   dur_wanted                  int64  [dimensionless]  ()  [0]
#   durunits                    int64  [dimensionless]  ()  [1]
#   end_time                   string  [dimensionless]  ()  ["2019-12-18T18:36:41"]
#   flipper_onoff           DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [1.000000, 1.000000, ..., 1.000000, 1.000000]
#
# ]
#   freq                        int64  [dimensionless]  ()  [1]
#   gd_prtn_chrg              float64  [dimensionless]  ()  [2.750211]
#   good_frames             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1461, 258]
#
# ]
#   good_uah_log            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64           [µAh]  (time)  [1.460050, 1.460050, ..., 0.257832, 0.257832]
#
# ]
#   goodfrm                     int64  [dimensionless]  ()  [2752]
#   icp_event               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:5, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000, 2019-12-16T17:53:49.000000000, ..., 2019-12-16T17:53:56.000000000, 2019-12-16T17:53:56.000000000]
# Data:
#                              string  [dimensionless]  (time)  ["CHANGE_PERIOD 1                                           ", "START_COLLECTION PERIOD 1 GF 0 RF 0 GUAH 0.000000         ", ..., "STOP_COLLECTION PERIOD 1 GF 344 RF 344 GUAH 0.343776 DUR 7", "END                                                       "]
#
# ]
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   is_running              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [0, 0]
#
# ]
#   is_waiting              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [0, 0]
#
# ]
#   measurement_id             string  [dimensionless]  ()  ["0"]
#   measurement_label          string  [dimensionless]  ()  [""]
#   measurement_subid          string  [dimensionless]  ()  ["0"]
#   measurement_type           string  [dimensionless]  ()  ["sans"]
#   mon_sum1                    int64  [dimensionless]  ()  [0]
#   mon_sum2                    int64  [dimensionless]  ()  [0]
#   mon_sum3                    int64  [dimensionless]  ()  [0]
#   monitor1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 9.819500)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [287.000000, 147.000000, ..., 14.000000, 3986.000000]  [287.000000, 147.000000, ..., 14.000000, 3986.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [1]
#
# ]
#   monitor2                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 20.313000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [6.000000, 11.000000, ..., 4.000000, 8.000000]  [6.000000, 11.000000, ..., 4.000000, 8.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [2]
#
# ]
#   monitor3                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 24.056000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [3]
#
# ]
#   monitor4                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.760000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [28.000000, 34.000000, ..., 11.000000, 25.000000]  [28.000000, 34.000000, ..., 11.000000, 25.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [4]
#
# ]
#   monitor5                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 29.650000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [5]
#
# ]
#   monitor_sum_1           DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32         [counts]  (time)  [0, 0]
#
# ]
#   nchannels                   int64  [dimensionless]  ()  [1000]
#   np_ratio                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   nperiods                    int64  [dimensionless]  ()  [1]
#   nspectra                    int64  [dimensionless]  ()  [114698]
#   period                  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1, 1]
#
# ]
#   period 1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:1, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000]
# Data:
#                                bool  [dimensionless]  (time)  [True]
#
# ]
#   periods                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:1, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1]
#
# ]
#   placeholder monitor_10  DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [10]
#
# ]
#   placeholder monitor_6   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [6]
#
# ]
#   placeholder monitor_7   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [7]
#
# ]
#   placeholder monitor_8   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [8]
#
# ]
#   placeholder monitor_9   DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[tof:1000, ]
# Coordinates:
#   position                vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   sample_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 25.300000)]
#   source_position         vector_3_float64              [m]  ()  [(0.000000, 0.000000, 0.000000)]
#   tof                       float64            [µs]  (tof [bin-edge])  [5.000000, 105.000000, ..., 99905.000000, 100000.000000]
# Data:
#                             float64         [counts]  (tof)  [0.000000, 0.000000, ..., 0.000000, 0.000000]  [0.000000, 0.000000, ..., 0.000000, 0.000000]
# Attributes:
#   instrument_name            string  [dimensionless]  ()  ["LARMOR"]
#   spectrum                    int32  [dimensionless]  ()  [9]
#
# ]
#   pol_arc                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.083941, -0.083941, ..., -0.083941, -0.083941]
#
# ]
#   pol_trans               DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [0.000000, 0.000000, ..., 0.000000, 0.000000]
#
# ]
#   proton_charge_by_period   float64  [dimensionless]  ()  [0.343776]
#   raw_frames              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1461, 258]
#
# ]
#   raw_uah_log             DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:29.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64           [µAh]  (time)  [1.460050, 1.460050, ..., 0.257832, 0.257832]
#
# ]
#   rawfrm                      int64  [dimensionless]  ()  [2752]
#   rb_proposal                 int64  [dimensionless]  ()  [1930522]
#   run_end                    string  [dimensionless]  ()  ["2019-12-18T18:36:41"]
#   run_header                 string  [dimensionless]  ()  ["LAR 49293 Dalgliesh,Raspino,Ho  LOKI Detector Test Dumm 16-DEC-2019  17:53:49     0.34"]
#   run_number                 string  [dimensionless]  ()  ["49338"]
#   run_start                  string  [dimensionless]  ()  ["2019-12-18T17:36:11"]
#   run_status              DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32  [dimensionless]  (time)  [1, 1]
#
# ]
#   run_title                  string  [dimensionless]  ()  ["RT1 a1=20x20 a2=6x8mm_SANS"]
#   running                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:49.000000000, 2019-12-16T17:53:56.000000000]
# Data:
#                                bool  [dimensionless]  (time)  [True, False]
#
# ]
#   s2south                 DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-0.000200, -0.000200, ..., -0.000200, -0.000200]
#
# ]
#   sample                   PyObject  [dimensionless]  ()  [<mantid.api._api.Sample object at 0x7f7f01590f80>]
#   smc100_1                DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:24, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [-125.000000, -125.000000, ..., -125.000000, -125.000000]
#
# ]
#   spinflipper_curr        DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:184, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:14.000000000, 2019-12-16T17:53:14.000000000, ..., 2019-12-19T22:22:32.000000000, 2019-12-20T03:26:14.000000000]
# Data:
#                             float64  [dimensionless]  (time)  [5.900000, 5.800000, ..., 5.900000, 5.900000]
#
# ]
#   start_time                 string  [dimensionless]  ()  ["2019-12-18T17:36:11"]
#   tot_prtn_chrg             float64  [dimensionless]  ()  [2.750211]
#   total_counts            DataArray  [dimensionless]  ()  [<scipp.DataArray>
# Dimensions: Sizes[time:2, ]
# Coordinates:
#   time                    datetime64             [ns]  (time)  [2019-12-16T17:53:29.000000000, 2019-12-16T17:53:57.000000000]
# Data:
#                               int32         [counts]  (time)  [0, 0]
#
# ]

# %% [markdown]
# Note how adding such offsets fails if we fail to specify a unit:

# %%
try:
    data.coords['tof'] += 2.3
except sc.UnitError as e:
    print(e)
# Out:
# Cannot add µs and dimensionless.

# %% [markdown]
# This has several advantages:
# - We are protected from accidential errors.
#   If someone changes the unit of data or metatdata without our knowledge, e.g., from `us` to `ms` this mechanism protects us from silent errors corrupting the data.
# - It makes the code clearer and more readable, both for others as well as for our future selves.

# %% [markdown]
# ### Step 5: A closer look at the data
#
# The 2-D plot we obtain above by default is often not very enlightening.
# Define:

# %%
counts = sc.sum(data, 'tof')

# %% [markdown]
# Exercises:
# 1. Create a plot of `counts` and also try the instrument view.
# 2. How many counts are there in total, in all spectra combined?
# 3. Plot a single spectrum of `data` as a 1-D plot using the slicing syntax to access the spectrum.

# %%
# slice is optional, making plot more readable in the documentation
counts['spectrum', 56000:62000].plot()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %%
scn.instrument_view(counts, norm='log')
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %%
# sc.sum(counts, 'spectrum') # would be another solution
sc.sum(data).value
# Out:
# 58142417.0

# %%
data['spectrum',10000].plot()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %% [markdown]
# As seen in the instrument view the detectors consist of 4 layers of tubes, each containing 7 straws.
# Let us try to split up our data, so we can compare layers.
# There are other (and probably better) ways to do this, but here we try to define an integer variable containing a layer index:

# %%
z = sc.geometry.z(data.coords['position'])
near = sc.min(z)
far = sc.max(z)
layer = ((z-near)*400).astype(sc.dtype.int32)
layer.unit = ''
layer.plot()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %% [markdown]
# Exercises:
# - Change the magic parameter `400` in the cell above until pixels fall cleanly into layers, either 4 layers of tubes or 12 layers of straws.
# - Store `layer` as a new coord in `data`.
# - Use `sc.groupby(data, group='layer').sum('spectrum')` to group spectra into layers.
# - Inspect and understand the HTML view of the result.
# - Plot the result.
#   There are two options:
#   - Use `plot` with `projection='1d'`
#   - Use `sc.plot` after collapsing dimensions, `sc.collapse(grouped, keep='tof')`
# - Bonus: When grouping by straw layers, there is a different number of straws in the center layer of each tube (3 instead of 2) due to the flower-pattern arrangement of straws.
#   Define a helper data array with data set to 1 for each spectrum, group by layers and sum over spectrum as above, and use this result to normalize the layer-grouped data from above to spectrum count.

# %%
# NOTE:
# - set magic factor to, e.g., 150 to group by straw layer
# - set magic factor to, e.g., 40 to group by tube layer
layer = ((z-near)*150).astype(sc.dtype.int32)
layer.unit = ''
data.coords['layer'] = layer
grouped = sc.groupby(data, group='layer').sum('spectrum')
grouped.plot(projection='1d')
sc.plot(sc.collapse(grouped, keep='tof'))
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…

# %%
norm = sc.DataArray(data=layer*0+1, coords={'layer':layer})
norm = sc.groupby(norm, group='layer').sum('spectrum')
sc.plot(sc.collapse(grouped/norm, keep='tof'))
# Out:
# VBox(children=(HBox(children=(VBox(children=(Button(icon='home', layout=Layout(padding='0px 0px 0px 0px', widt…
